# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dist1, dist2 = np.random.normal(size=(2,100)), np.random.normal(loc=1, size=(2,100))

# %%
plt.scatter(dist1[0],dist1[1])
plt.scatter(dist2[0],dist2[1])
